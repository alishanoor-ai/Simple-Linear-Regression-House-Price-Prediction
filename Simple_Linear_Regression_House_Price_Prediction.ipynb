# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = {
    'House_Size': [800, 1000, 1200, 1500, 1800, 2000, 2200, 2500],
    'House_Price': [1600000, 2000000, 2400000, 3000000, 3600000, 4000000, 4400000, 5000000]
}

df = pd.DataFrame(data)

df
# Out:
#    House_Size  House_Price
# 0         800      1600000
# 1        1000      2000000
# 2        1200      2400000
# 3        1500      3000000
# 4        1800      3600000
# 5        2000      4000000
# 6        2200      4400000
# 7        2500      5000000

# %%
print("Dataset Shape:", df.shape)
print("\nDataset Information:")
df.info()

print("\nMissing Values:")
print(df.isnull().sum())

print("\nStatistical Summary:")
print(df.describe())
# Out:
# Dataset Shape: (8, 2)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   House_Size   8 non-null      int64
#  1   House_Price  8 non-null      int64
# dtypes: int64(2)
# memory usage: 260.0 bytes
#
# Missing Values:
# House_Size     0
# House_Price    0
# dtype: int64
#
# Statistical Summary:
#         House_Size   House_Price
# count     8.000000  8.000000e+00
# mean   1625.000000  3.250000e+06
# std     601.783065  1.203566e+06
# min     800.000000  1.600000e+06
# 25%    1150.000000  2.300000e+06
# 50%    1650.000000  3.300000e+06
# 75%    2050.000000  4.100000e+06
# max    2500.000000  5.000000e+06

# %%
X = df[['House_Size']]
y = df['House_Price']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y)

plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price")
plt.title("House Size vs House Price")

plt.show()

# %%
plt.scatter(X, y)

plt.plot(X, model.predict(X))

plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price")
plt.title("Linear Regression: House Size vs House Price")

plt.show()

# %%
new_house = [[1700]]

prediction = model.predict(new_house)

print("Predicted House Price:", prediction[0])
# Out:
# Predicted House Price: 3400000.0
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_houses = [[1300], [1700], [2100], [2800]]

predictions = model.predict(new_houses)

for size, price in zip(new_houses, predictions):
    print(f"{size[0]} sq ft house → Predicted Price: {price:,.0f}")
# Out:
# 1300 sq ft house → Predicted Price: 2,600,000
# 1700 sq ft house → Predicted Price: 3,400,000
# 2100 sq ft house → Predicted Price: 4,200,000
# 2800 sq ft house → Predicted Price: 5,600,000
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = model.predict(X)

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R² Score:", r2)
# Out:
# Mean Absolute Error (MAE): 5.529727786779404e-10
# Mean Squared Error (MSE): 4.404571325722362e-19
# R² Score: 1.0

# %%
plt.scatter(X, y, label="Actual Data")

plt.plot(X, y_pred, label="Regression Line")

plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price")
plt.title("House Price Prediction using Linear Regression")

plt.legend()
plt.show()
